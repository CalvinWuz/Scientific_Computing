# %% [markdown]
# <a href="https://colab.research.google.com/github/CalvinWuz/Scientific_Computing/blob/main/2802498103_Ida_Bagus_Gede_Calvin_Suta_Subagia_Manuaba_Scientific_Computing_Lab_Sesi_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a = [ [8,3,-3], [-2,-8,5], [3,5,10]]

# Find Diagonal Coefficient
diag = np.diag(np.abs(a))

#Find row sum without diagonal
off_diag = np.sum(np.abs(a), axis=1) - diag

if np.all(diag > off_diag):
    print('matrix is diagonally dominant')
else:
    print('not diagonally dominant')
# Out:
# matrix is diagonally dominant

# %%
print('Iteration results')
print(' k,  x1,  x2,  x3')
x1 = 0
x2 = 0
x3 = 0
for k in range(1,50) :
  x1 = (14-3*x2+3*x3)/8
  x2 = (5+2*x1-5*x3)/(-8)
  x3 = (-8-3*x1-5*x2)/10
  x_new = np.array([x1,x2,x3])
print('Iteration results')
print(' k,  x1,  x2,  x3')
x1 = 0
x2 = 0
x3 = 0
import numpy as np
epsilon = 1e-6 # You need to define epsilon
converged = False # initialize converged variable
x_old = np.array([x1,x2,x3]) # initialize x_old
for k in range(1,50) :
  x1 = (14-3*x2+3*x3)/8
  x2 = (5+2*x1-5*x3)/(-8)
  x3 = (-8-3*x1-5*x2)/10
  x_new = np.array([x1,x2,x3])
  print(k,x1,x2,x3)
  dx = np.sqrt(np.dot(x_new-x_old,x_new-x_old))
  if dx < epsilon:
    converged = True
    print('Converged!')
    break
  x_old = x_new
if not converged:
    print('Not converge, increase the # of iterations')
    break
  x_old = x_new
  if not converged:
    print('Not converge, increase the # of iterations')
# Out:
#   File "<tokenize>", line 35
#     x_old = x_new
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
print('Iteration results')
print(' k,  x1,  x2,  x3')
x1 = 0
x2 = 0
x3 = 0
import numpy as np
epsilon = 1e-6 # You need to define epsilon
converged = False # initialize converged variable
x_old = np.array([x1,x2,x3]) # initialize x_old
for k in range(1,50) :
  x1 = (14-3*x2+3*x3)/8
  x2 = (5+2*x1-5*x3)/(-8)
  x3 = (-8-3*x1-5*x2)/10
  x_new = np.array([x1,x2,x3])
  print(k,x1,x2,x3)
  dx = np.sqrt(np.dot(x_new-x_old,x_new-x_old))
  if dx < epsilon:
    converged = True
    print('Converged!')
    break # Exit the loop if converged
  x_old = x_new
# The following block was incorrectly indented
if not converged:
    print('Not converge, increase the # of iterations')
    # The break statement here was redundant, and the indentation was causing the error.
    # break was removed and the indentation level was adjusted to match the outer for loop
# removed the extra x_old = x_new line and if statement as they were duplicates.
# Out:
# Iteration results
#  k,  x1,  x2,  x3
# 1 1.75 -1.0625 -0.79375
# 2 1.85078125 -1.5837890625 -0.56333984375
# 3 2.13266845703125 -1.5102545166015626 -0.6846732788085935
# 4 2.0595929641723636 -1.567819040298462 -0.6339683691024781
# 5 2.100194001698494 -1.5462787311136723 -0.6569188349527121
# 6 2.08350996106036 -1.556451762110535 -0.6468271072628407
# 7 2.0911092455678855 -1.5520442534312466 -0.6513106469547424
# 8 2.0877751024286892 -1.5540129299538863 -0.6493260657516635
# 9 2.0892575740758335 -1.5531431846137482 -0.6502056799158759
# 10 2.088601564261702 -1.5535289410128479 -0.6498159987720867
# 11 2.0888923533402854 -1.5533580875676256 -0.6499886622182729
# 12 2.0887635345060076 -1.5534337975129224 -0.649912161595341
# 13 2.088820613469093 -1.5534002543643612 -0.6499460568585473
# 14 2.08879532406468 -1.553415116552762 -0.649931038943023
# 15 2.0888065291036524 -1.5534085316153026 -0.6499376929234444
# 16 2.088801564509447 -1.5534114492045146 -0.6499347447505768
# ...

# %%
import numpy as np
# Define matrix A and vector y
A = np.array([[4, 3, -5], [-2, -4, 5], [8, 8, 0]])
y = np.array([2, 5, -3])

# Solve for x
x = np.linalg.solve(A, y)

# Print the solution
print("Solution for x:")
print(x)
# Out:
# Solution for x:
# [ 2.20833333 -2.58333333 -0.18333333]

# %%
# Define matrix A and vector y
A = np.array([[4, 3, -5],
              [-2, -4, 5],
               [8, 8, 0]])
y = np.array([2, 5, -3])

# Find the inverse of A
A_inv = np.linalg.inv(A)

# Compute the solution x
x = A_inv.dot(y)

# Print the solution
print(x)
# Out:
# [ 2.20833333 -2.58333333 -0.18333333]

# %%
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

#generate x and y
x = np.linspace(0,1, 101)
y = 1 + x + x * np.random.random(len(x))

# assemble matrix A
A = np.vstack([x, np.ones(len(x))]).T

# turn y into a column vector
y = y[:, np.newaxis]

# direct least square regression
alpha = np.dot((np.dot(np.linalg.inv(np.dot(A.T,A)),A.T)),y)
print(alpha)
# Out:
# [[1.45452226]
#  [1.01120973]]

# %%
# plot the data and regression line
plt.figure(figsize=(10, 8))
plt.plot(x,y, 'b', label = 'Data')
plt.plot(x, alpha[0]*x + alpha[1], 'r', label= 'Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.show()

# %%
import numpy as np
from scipy import optimize
import matplotlib.pyplot as plt

#generate x and y
x = np.linspace(0,1, 101)
y = 1 + x + x * np.random.random(len(x))

# assemble matrix A
A = np.vstack([x, np.ones(len(x))]).T

# turn y into a column vector
y = y[:, np.newaxis]

# calculate pseudoinverse
pinv = np.linalg.pinv(A)

# compute the solution
alpha = pinv.dot(y)

#print the coefficients
print(alpha)
# Out:
# [[1.68863711]
#  [0.94785017]]

# %%
import numpy as np
#generate x and y
x = np.linspace(0,1, 101)
y = 1 + x + x * np.random.random(len(x))

# assemble matrix A
A = np.vstack([x, np.ones(len(x))]).T

# turn y into a column vector
y = y[:, np.newaxis]

# use least squares function
alpha = np.linalg.lstsq(A, y, rcond=None)[0]

#print the coefficients
print(alpha)
# Out:
# [[1.55741144]
#  [0.98290085]]

# %%
import numpy as np
from scipy import optimize

# generate x and y data points
x= np.linspace(0,1, 101)
y = 1 + x + x * np.random.random(len(x))

# Define the model function
def func(x, a, b):
  return a * x + b
import numpy as np
from scipy import optimize

# generate x and y data points
x= np.linspace(0,1, 101)
y = 1 + x + x * np.random.random(len(x))

# Define the model function
def func(x, a, b):
  return a * x + b

# use curve fitting to find the best parameters
alpha, _ = optimize.curve_fit(func, x, y)

# print the best parameters
print(alpha)
print(alpha)
# Out:
# [1.49280237 1.00184215]
# [1.49280237 1.00184215]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [0, 1, 2, 3]
y = [0, 1, 4, 9]
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

ts = pd.Series(np.random.randm(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot();
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-c2f781d8b75e> in <cell line: 0>()
#       2 import pandas as pd
#       3
# ----> 4 ts = pd.Series(np.random.randm(1000), index=pd.date_range("1/1/2000", periods=1000))
#       5 ts = ts.cumsum()
#       6 ts.plot();
#
# AttributeError: module 'numpy.random' has no attribute 'randm'

# %%
import matplotlib.pyplot as plt
import pandas as pd

ts = pd.Series(np.random.rand(1000), index=pd.date_range("1/1/2000", periods=1000))
ts = ts.cumsum()
ts.plot();
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-94d16a61d15b> in <cell line: 0>()
#       2 import pandas as pd
#       3
# ----> 4 ts = pd.Series(np.random.rand(1000), index=pd.date_range("1/1/2000", periods=1000))
#       5 ts = ts.cumsum()
#       6 ts.plot();
#
# NameError: name 'np' is not defined

# %%
df = pd.DataFrame(np.random.randn(1000, 4), index =ts. index, columns=list("ABCD"))

df = df.cumsum()

plt.figure();

df.plot();
